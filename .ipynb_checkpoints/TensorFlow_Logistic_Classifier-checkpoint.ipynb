# %%
import tensorflow as tf
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import math
def get_weights(n_features,n_labels):
    # Return Tensorflow weight
    weights = tf.Variable(tf.random_normal([n_features,n_labels]))
    return weights

def get_biases(n_labels):
    # Return Tensorflow bias
    bias = tf.Variable(tf.random_normal([n_labels])) 
    return bias
def linear_function(input,w,b):
    return tf.add(tf.matmul(input,w),b)
def batches(batch_size,features,labels):
    assert len(features)==len(labels)
#     Create batches of features and labels
    out_batches = []
    sample_size=len(features)
   
    for start_i in range(0,sample_size,batch_size):
        end_i=start_i+batch_size
        batch=[features[start_i:end_i],labels[start_i:end_i]]
        out_batches.append(batch)
   
    return out_batches
        
def print_epoch_stats(epoch_i, sess, last_features, last_labels):
    #     Print cost and validation accuracy of an epoch
    current_cost=sess.run(cost,feed_dict={features:last_features,labels:last_labels})
    valid_accuracy=sess.run(accuracy,feed_dict={features:last_features,labels:last_labels})
    print('Epoch: {:<4} - Cost: {:<8.3} Valid Accuracy: {:<5.3}'.format(
        epoch_i,
        current_cost,
        valid_accuracy))

# %%
#Define a function to load feature and lables from data sets
def mnist_features_labels():
   
   
    #Download MNIST data set if not present in local
    mnist= input_data.read_data_sets('datasets/mnist', one_hot=True)
    #Extract features and lables from the dataset
    
    train_features=mnist.train.images
    test_features = mnist.test.images
    
    train_labels = mnist.train.labels.astype(np.float32)
    test_labels = mnist.test.labels.astype(np.float32)
    return train_features,train_labels,test_features,test_labels

# %%
# Tranning the data
# train_features,train_labels = mnist_features_labels(n_classes)
train_features,train_labels,test_features,test_labels = mnist_features_labels()
# Out:
# Extracting datasets/mnist/train-images-idx3-ubyte.gz
# Extracting datasets/mnist/train-labels-idx1-ubyte.gz
# Extracting datasets/mnist/t10k-images-idx3-ubyte.gz
# Extracting datasets/mnist/t10k-labels-idx1-ubyte.gz

# %%
# number of the features of 28x28 image is = 784
n_features=784
# number of lables 
n_classes = 10

#Define the learning rate
learning_rate=0.01

# Place holder for features and lables
features = tf.placeholder(tf.float32,[None,n_features])
labels = tf.placeholder(tf.float32,[None,n_classes])

# Weight and Biases 
w = get_weights(n_features,n_classes)
b = get_biases(n_classes)

# Calculte the logits. Linear Model xw+b
logits = linear_function(features,w,b)
print(logits)
# Out:
# Tensor("Add:0", shape=(?, 10), dtype=float32)

# %%
# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=labels))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost)


# Calculte the accuracy 
correct_prediction = tf.equal(tf.argmax(logits,1), tf.argmax(labels, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

    
# Batch size
batch_size=128
epochs =150
assert batch_size is not None, 'Must set the batch size'
train_batchs= batches(batch_size,train_features,train_labels)
init = tf.global_variables_initializer()
with tf.Session() as sess:
    # initialize the session variables
    sess.run(init)
    
    for epoch_i in range(epochs):
        # Run the optimizer and get the loss
        for batch_feature,batch_label in train_batchs:
            train_feed_dict={features:batch_feature,labels:batch_label}
            sess.run(optimizer,feed_dict=train_feed_dict)
        print_epoch_stats(epoch_i,sess,batch_feature,batch_label)
        
    #Calculate the accuracy for test data
    test_accuracy=sess.run(accuracy,feed_dict={features:test_features,labels:test_labels})
    
# Loss
print('Test Accuracy: {}'.format(test_accuracy))
# Out:
# Epoch: 0    - Cost: 11.3     Valid Accuracy: 0.0341
# Epoch: 1    - Cost: 10.4     Valid Accuracy: 0.0568
# Epoch: 2    - Cost: 9.64     Valid Accuracy: 0.102
# Epoch: 3    - Cost: 9.05     Valid Accuracy: 0.102
# Epoch: 4    - Cost: 8.54     Valid Accuracy: 0.102
# Epoch: 5    - Cost: 8.07     Valid Accuracy: 0.125
# Epoch: 6    - Cost: 7.64     Valid Accuracy: 0.136
# Epoch: 7    - Cost: 7.23     Valid Accuracy: 0.159
# Epoch: 8    - Cost: 6.86     Valid Accuracy: 0.17
# Epoch: 9    - Cost: 6.51     Valid Accuracy: 0.193
# Epoch: 10   - Cost: 6.2      Valid Accuracy: 0.193
# Epoch: 11   - Cost: 5.91     Valid Accuracy: 0.216
# Epoch: 12   - Cost: 5.65     Valid Accuracy: 0.25
# Epoch: 13   - Cost: 5.42     Valid Accuracy: 0.273
# Epoch: 14   - Cost: 5.21     Valid Accuracy: 0.295
# Epoch: 15   - Cost: 5.02     Valid Accuracy: 0.307
# Epoch: 16   - Cost: 4.84     Valid Accuracy: 0.318
# Epoch: 17   - Cost: 4.68     Valid Accuracy: 0.318
# Epoch: 18   - Cost: 4.53     Valid Accuracy: 0.341
# Epoch: 19   - Cost: 4.39     Valid Accuracy: 0.341
# Epoch: 20   - Cost: 4.26     Valid Accuracy: 0.375
# Epoch: 21   - Cost: 4.14     Valid Accuracy: 0.375
# Epoch: 22   - Cost: 4.03     Valid Accuracy: 0.398
# Epoch: 23   - Cost: 3.93     Valid Accuracy: 0.398
# Epoch: 24   - Cost: 3.84     Valid Accuracy: 0.409
# Epoch: 25   - Cost: 3.75     Valid Accuracy: 0.409
# Epoch: 26   - Cost: 3.67     Valid Accuracy: 0.409
# Epoch: 27   - Cost: 3.59     Valid Accuracy: 0.432
# Epoch: 28   - Cost: 3.52     Valid Accuracy: 0.443
# Epoch: 29   - Cost: 3.45     Valid Accuracy: 0.443
# Epoch: 30   - Cost: 3.38     Valid Accuracy: 0.443
# Epoch: 31   - Cost: 3.32     Valid Accuracy: 0.455
# Epoch: 32   - Cost: 3.26     Valid Accuracy: 0.455
# Epoch: 33   - Cost: 3.2      Valid Accuracy: 0.455
# Epoch: 34   - Cost: 3.15     Valid Accuracy: 0.455
# Epoch: 35   - Cost: 3.09     Valid Accuracy: 0.466
# Epoch: 36   - Cost: 3.04     Valid Accuracy: 0.466
# Epoch: 37   - Cost: 3.0      Valid Accuracy: 0.477
# Epoch: 38   - Cost: 2.95     Valid Accuracy: 0.477
# Epoch: 39   - Cost: 2.9      Valid Accuracy: 0.489
# Epoch: 40   - Cost: 2.86     Valid Accuracy: 0.5
# Epoch: 41   - Cost: 2.82     Valid Accuracy: 0.5
# Epoch: 42   - Cost: 2.78     Valid Accuracy: 0.5
# Epoch: 43   - Cost: 2.74     Valid Accuracy: 0.5
# Epoch: 44   - Cost: 2.7      Valid Accuracy: 0.5
# Epoch: 45   - Cost: 2.66     Valid Accuracy: 0.5
# Epoch: 46   - Cost: 2.63     Valid Accuracy: 0.5
# Epoch: 47   - Cost: 2.59     Valid Accuracy: 0.511
# Epoch: 48   - Cost: 2.56     Valid Accuracy: 0.511
# Epoch: 49   - Cost: 2.52     Valid Accuracy: 0.511
# Epoch: 50   - Cost: 2.49     Valid Accuracy: 0.511
# Epoch: 51   - Cost: 2.46     Valid Accuracy: 0.523
# Epoch: 52   - Cost: 2.43     Valid Accuracy: 0.523
# Epoch: 53   - Cost: 2.4      Valid Accuracy: 0.523
# Epoch: 54   - Cost: 2.37     Valid Accuracy: 0.534
# Epoch: 55   - Cost: 2.35     Valid Accuracy: 0.534
# Epoch: 56   - Cost: 2.32     Valid Accuracy: 0.534
# Epoch: 57   - Cost: 2.3      Valid Accuracy: 0.557
# Epoch: 58   - Cost: 2.27     Valid Accuracy: 0.557
# Epoch: 59   - Cost: 2.25     Valid Accuracy: 0.557
# Epoch: 60   - Cost: 2.22     Valid Accuracy: 0.557
# Epoch: 61   - Cost: 2.2      Valid Accuracy: 0.568
# Epoch: 62   - Cost: 2.18     Valid Accuracy: 0.568
# Epoch: 63   - Cost: 2.16     Valid Accuracy: 0.568
# Epoch: 64   - Cost: 2.13     Valid Accuracy: 0.568
# Epoch: 65   - Cost: 2.11     Valid Accuracy: 0.58
# Epoch: 66   - Cost: 2.09     Valid Accuracy: 0.58
# Epoch: 67   - Cost: 2.08     Valid Accuracy: 0.58
# Epoch: 68   - Cost: 2.06     Valid Accuracy: 0.591
# Epoch: 69   - Cost: 2.04     Valid Accuracy: 0.591
# Epoch: 70   - Cost: 2.02     Valid Accuracy: 0.602
# Epoch: 71   - Cost: 2.0      Valid Accuracy: 0.602
# Epoch: 72   - Cost: 1.99     Valid Accuracy: 0.602
# Epoch: 73   - Cost: 1.97     Valid Accuracy: 0.625
# Epoch: 74   - Cost: 1.95     Valid Accuracy: 0.625
# Epoch: 75   - Cost: 1.94     Valid Accuracy: 0.625
# Epoch: 76   - Cost: 1.92     Valid Accuracy: 0.625
# Epoch: 77   - Cost: 1.91     Valid Accuracy: 0.625
# Epoch: 78   - Cost: 1.89     Valid Accuracy: 0.625
# Epoch: 79   - Cost: 1.88     Valid Accuracy: 0.636
# Epoch: 80   - Cost: 1.86     Valid Accuracy: 0.636
# Epoch: 81   - Cost: 1.85     Valid Accuracy: 0.636
# Epoch: 82   - Cost: 1.84     Valid Accuracy: 0.636
# Epoch: 83   - Cost: 1.82     Valid Accuracy: 0.636
# Epoch: 84   - Cost: 1.81     Valid Accuracy: 0.636
# Epoch: 85   - Cost: 1.8      Valid Accuracy: 0.636
# Epoch: 86   - Cost: 1.78     Valid Accuracy: 0.648
# Epoch: 87   - Cost: 1.77     Valid Accuracy: 0.648
# Epoch: 88   - Cost: 1.76     Valid Accuracy: 0.659
# Epoch: 89   - Cost: 1.75     Valid Accuracy: 0.67
# Epoch: 90   - Cost: 1.74     Valid Accuracy: 0.67
# Epoch: 91   - Cost: 1.73     Valid Accuracy: 0.682
# Epoch: 92   - Cost: 1.72     Valid Accuracy: 0.682
# Epoch: 93   - Cost: 1.7      Valid Accuracy: 0.682
# Epoch: 94   - Cost: 1.69     Valid Accuracy: 0.693
# Epoch: 95   - Cost: 1.68     Valid Accuracy: 0.693
# Epoch: 96   - Cost: 1.67     Valid Accuracy: 0.693
# Epoch: 97   - Cost: 1.66     Valid Accuracy: 0.693
# Epoch: 98   - Cost: 1.65     Valid Accuracy: 0.693
# Epoch: 99   - Cost: 1.64     Valid Accuracy: 0.693
# Epoch: 100  - Cost: 1.63     Valid Accuracy: 0.693
# Epoch: 101  - Cost: 1.63     Valid Accuracy: 0.693
# Epoch: 102  - Cost: 1.62     Valid Accuracy: 0.682
# Epoch: 103  - Cost: 1.61     Valid Accuracy: 0.682
# Epoch: 104  - Cost: 1.6      Valid Accuracy: 0.682
# Epoch: 105  - Cost: 1.59     Valid Accuracy: 0.682
# Epoch: 106  - Cost: 1.58     Valid Accuracy: 0.682
# Epoch: 107  - Cost: 1.57     Valid Accuracy: 0.682
# Epoch: 108  - Cost: 1.57     Valid Accuracy: 0.682
# Epoch: 109  - Cost: 1.56     Valid Accuracy: 0.693
# Epoch: 110  - Cost: 1.55     Valid Accuracy: 0.693
# Epoch: 111  - Cost: 1.54     Valid Accuracy: 0.693
# Epoch: 112  - Cost: 1.53     Valid Accuracy: 0.705
# Epoch: 113  - Cost: 1.53     Valid Accuracy: 0.705
# Epoch: 114  - Cost: 1.52     Valid Accuracy: 0.705
# Epoch: 115  - Cost: 1.51     Valid Accuracy: 0.705
# Epoch: 116  - Cost: 1.51     Valid Accuracy: 0.705
# Epoch: 117  - Cost: 1.5      Valid Accuracy: 0.716
# Epoch: 118  - Cost: 1.49     Valid Accuracy: 0.716
# Epoch: 119  - Cost: 1.49     Valid Accuracy: 0.727
# Epoch: 120  - Cost: 1.48     Valid Accuracy: 0.727
# Epoch: 121  - Cost: 1.47     Valid Accuracy: 0.727
# Epoch: 122  - Cost: 1.47     Valid Accuracy: 0.739
# Epoch: 123  - Cost: 1.46     Valid Accuracy: 0.75
# Epoch: 124  - Cost: 1.45     Valid Accuracy: 0.75
# Epoch: 125  - Cost: 1.45     Valid Accuracy: 0.75
# Epoch: 126  - Cost: 1.44     Valid Accuracy: 0.75
# Epoch: 127  - Cost: 1.44     Valid Accuracy: 0.75
# Epoch: 128  - Cost: 1.43     Valid Accuracy: 0.75
# Epoch: 129  - Cost: 1.43     Valid Accuracy: 0.75
# Epoch: 130  - Cost: 1.42     Valid Accuracy: 0.75
# Epoch: 131  - Cost: 1.41     Valid Accuracy: 0.75
# Epoch: 132  - Cost: 1.41     Valid Accuracy: 0.75
# Epoch: 133  - Cost: 1.4      Valid Accuracy: 0.75
# Epoch: 134  - Cost: 1.4      Valid Accuracy: 0.75
# Epoch: 135  - Cost: 1.39     Valid Accuracy: 0.75
# Epoch: 136  - Cost: 1.39     Valid Accuracy: 0.75
# Epoch: 137  - Cost: 1.38     Valid Accuracy: 0.75
# Epoch: 138  - Cost: 1.38     Valid Accuracy: 0.75
# Epoch: 139  - Cost: 1.37     Valid Accuracy: 0.75
# Epoch: 140  - Cost: 1.37     Valid Accuracy: 0.75
# Epoch: 141  - Cost: 1.36     Valid Accuracy: 0.75
# Epoch: 142  - Cost: 1.36     Valid Accuracy: 0.761
# Epoch: 143  - Cost: 1.36     Valid Accuracy: 0.761
# Epoch: 144  - Cost: 1.35     Valid Accuracy: 0.773
# Epoch: 145  - Cost: 1.35     Valid Accuracy: 0.773
# Epoch: 146  - Cost: 1.34     Valid Accuracy: 0.773
# Epoch: 147  - Cost: 1.34     Valid Accuracy: 0.773
# Epoch: 148  - Cost: 1.33     Valid Accuracy: 0.773
# Epoch: 149  - Cost: 1.33     Valid Accuracy: 0.773
# Test Accuracy: 0.7659000158309937
